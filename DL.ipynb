# %%
# 🔹 Basic Difference   ML VS DL 
'''  Deep Learning ek advanced part hai Machine Learning 
Machine Learning (ML) = Algorithms jo data se seekhte hain
Deep Learning (DL) = ML ka advanced part jo neural networks use karta hai

| Feature             | Machine Learning                   | Deep Learning                            |
| ------------------- | ---------------------------------- | ---------------------------------------- |
| Definition          | Data se patterns seekhna           | Neural networks se deep patterns seekhna |
| Data Need           | Kam data me bhi kaam chal jata hai | Bohot zyada data chahiye                 |
| Feature Engineering | Manually karna padta hai           | Automatically ho jata hai                |
| Speed (Training)    | Fast                               | Slow (heavy computation)                 |
| Accuracy            | Moderate                           | High (especially big data me)            |
| Hardware            | Normal CPU chalega                 | GPU/High power chahiye                   |
| Examples            | Spam detection, recommendations    | Image recognition, voice assistants      |

uuuu
'''

# 🔹 Neural Network
'''  
Neural Network ek aisa system hai jo computer ko human brain ki tarah sochne aur seekhne me help karta hai

🔹 Neural Network ka Structure

        👉 Input Layer
             Data yahan se enter hota hai
        👉 Hidden Layers
            Yahan processing hoti hai (main kaam yahi hota hai)
        👉 Output Layer
             Final result milta hai
'''

# ✅ Deep Learning (DL) kab use kare?
'''
1. Data bahut zyada ho
    Big data ho to DL best perform karta hai
2. Complex problem ho
        Jaise:
        Image recognition 📸
        Voice recognition 🎤
        Self-driving cars 🚗
3. Feature engineering mushkil ho
    DL khud features find kar leta hai
4. High accuracy chahiye
    Especially complex tasks me 

'''

# %%
# 🔹 Activation Function kya hota hai?
'''

👉 Ye decide karta hai:

Neuron activate (ON) hoga ya nahi
Matlab output aage pass karna hai ya nahi

y = x1.w1+x2.w2+bias


'''

# 🔹 Sigmoid Function kya hota hai?

''' 
👉 Ye output ko 0 se 1 ke beech me convert karta hai  
📌 Formula: 
1/(1+e^y)


👉 Deep networks me learning slow ho jati hai  
ReLU zyada use hota hai 
'''

# %%
# 🔹 1. Constant (Fixed Value)
'''

👉 Constant = value jo change nahi hoti

✅ Code (TensorFlow)
import tensorflow as tf

    x = tf.constant([1, 2, 3])
    print(x)

👍 Advantage
    Safe (value change nahi hoti)
Debugging easy
👎 Disadvantage
    Flexible nahi hai (update nahi kar sakte)

'''
# 🔹 2. Variable (Changeable Value) 
'''
 x = tf.Variable([1.0, 2.0, 3.0])

👎 Disadvantage
Thoda complex manage karna 
'''
# 🔹 3. Sequential Model 
'''
👉 Layer-by-layer  exexute (same as pipline ) 
 simple neural network
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1)
]) 

👍 Advantage
    Easy to use (beginner friendly)
    Simple problems ke liye best
👎 Disadvantage
    Complex architecture (multiple inputs/output) nahi bana sakte
'''

# 🔹 4. Dense Layer (Fully Connected Layer)
'''
👉 Har neuron sab neurons se connected hota hai

from tensorflow.keras.layers import Dense

layer = Dense(10, activation='relu') 


👍 Advantage
    Powerful for learning patterns
    Most common layer
👎 Disadvantage
    Zyada parameters → slow ho sakta hai
    Overfitting ka risk
'''
# 🔹 5. random.normal (Random Data Generation)
'''
👉 Random values generate karta hai (normal distribution se) 

👍 Advantage
    Weight initialization me use hota hai
    Testing ke liye useful
👎 Disadvantage
    Random hone ki wajah se result har baar change hota hai
'''
# Epoch ka matlab hai:
'''
“Poore training dataset ko ek baar model ke through pass karna”

🔹 Simple Example

Maan le tere paas 100 images ka data hai 📸

Model ne ek baar saare 100 images dekh liye → 1 Epoch
Agar 10 baar same data se training hui → 10 Epochs

'''

# %%
# 🔹 1. Linear Method (Linear Layer)
'''
y = Wx + b
👍 Advantage
Simple aur fast
Base building block hai
👎 Disadvantage
Sirf linear relation seekhta hai
👉 Complex patterns nahi seekh sakta

✅ Kyu use kare?
Data ko transform (Wx + b) karne ke liye
Neural network ka base building block hai
Har model me almost use hota hi hai
❌ Kab use na kare?
Agar sirf linear layers hi use karega (no activation)
👉 Model sirf straight line relation seekhega
👉 Complex problems fail ho jayenge

''' 
# 🔹 2. ReLU Activation Function
'''

✅ Kyu use kare?
Fast training ⚡
Deep networks me best kaam karta hai
Vanishing gradient problem kam karta hai

👉 Isliye hidden layers me mostly ReLU default choice hota hai

❌ Kab use na kare?
Agar output me negative values important hain
👉 ReLU unko 0 bana deta hai
Kabhi-kabhi:
👉 “Dead neurons” ho jate hain (output always 0)

'''

#  Agar .view(-1,1) na kare to?
'''
Kabhi kabhi code chal bhi jayega, lekin:

❌ Loss function warning de sakta hai
❌ Shape mismatch error aa sakta hai
❌ Training incorrect ho sakti hai
'''
